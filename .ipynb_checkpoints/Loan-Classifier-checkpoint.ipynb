# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import colors 
from matplotlib.ticker import PercentFormatter 
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn import preprocessing 
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import classification_report, confusion_matrix

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.utils import to_categorical

import datetime
import math

# %%
# Creating histogram using matplotlib
def createHistUsingPlt(df_column, n_bins, xlabel, ylabel, title, legend, watermarktext):
    fig, axs = plt.subplots(1, 1, figsize =(10, 7), tight_layout = True)
    # Remove axes splines  
    for s in ['top', 'bottom', 'left', 'right']:  
        axs.spines[s].set_visible(False)
    
    # Remove x, y ticks 
    axs.xaxis.set_ticks_position('none')  
    axs.yaxis.set_ticks_position('none')  

    # Add padding between axes and labels  
    axs.xaxis.set_tick_params(pad = 5)  
    axs.yaxis.set_tick_params(pad = 10)

    # Add x, y gridlines  
    axs.grid(b = True, color ='grey',  
            linestyle ='-.', linewidth = 0.5,  
            alpha = 0.6)  

    # Add Text watermark  
    fig.text(0.9, 0.15, watermarktext,  
             fontsize = 12,  
             color ='red', 
             ha ='left', 
             va ='top',  
             alpha = 0.7)

    data = np.array(df_column)

    N, bins, patches = plt.hist(data, bins = n_bins)

    # Setting color 
    fracs = ((N**(1 / 5)) / N.max()) 
    norm = colors.Normalize(fracs.min(), fracs.max()) 

    for thisfrac, thispatch in zip(fracs, patches): 
        color = plt.cm.viridis(norm(thisfrac)) 
        thispatch.set_facecolor(color) 

    # Adding extra features     
    plt.xlabel(xlabel) 
    plt.ylabel(ylabel)
    plt.legend(legend) 
    plt.title(title) 

    # Show plot 
    plt.show()

# %%
#Columns having null or blank values
def columnNamessHavingNull(df):
    colshavingnull = []
    cols = df.isnull().any().to_dict()
    for x in cols:
        if (cols[x]):
            colshavingnull.append(x)
    return colshavingnull

# %%
def columnDetailsHaivngNull(colshavingnull):
    total = 0
    details_nullcolumns = {}
    for col in colshavingnull:
        col_count_null = np.where(pd.isnull(df[col]))
        details_nullcolumns[col] =  len(col_count_null[0])
#         print(f"{col}-----{len(col_count_null[0])}")
        total = total + len(col_count_null[0])
#     print("\n")
#     print(f"Total records are: {total}" )
    details_nullcolumns["Total"] = total
    return details_nullcolumns

# %%
df = pd.read_csv('../Practice/DATA/lending_club_loan_two.csv')

# %%
df.describe().transpose()
# Out:
#                          count          mean           std     min       25%  \
# loan_amnt             396030.0  14113.888089   8357.441341  500.00   8000.00
# int_rate              396030.0     13.639400      4.472157    5.32     10.49
# installment           396030.0    431.849698    250.727790   16.08    250.33
# annual_inc            396030.0  74203.175798  61637.621158    0.00  45000.00
# dti                   396030.0     17.379514     18.019092    0.00     11.28
# open_acc              396030.0     11.311153      5.137649    0.00      8.00
# pub_rec               396030.0      0.178191      0.530671    0.00      0.00
# revol_bal             396030.0  15844.539853  20591.836109    0.00   6025.00
# revol_util            395754.0     53.791749     24.452193    0.00     35.80
# total_acc             396030.0     25.414744     11.886991    2.00     17.00
# mort_acc              358235.0      1.813991      2.147930    0.00      0.00
# pub_rec_bankruptcies  395495.0      0.121648      0.356174    0.00      0.00
#
#                            50%       75%         max
# loan_amnt             12000.00  20000.00    40000.00
# int_rate                 13.33     16.49       30.99
# installment             375.43    567.30     1533.81
# annual_inc            64000.00  90000.00  8706582.00
# dti                      16.91     22.98     9999.00
# open_acc                 10.00     14.00       90.00
# pub_rec                   0.00      0.00       86.00
# revol_bal             11181.00  19620.00  1743266.00
# revol_util               54.80     72.90      892.30
# total_acc                24.00     32.00      151.00
# mort_acc                  1.00      3.00       34.00
# pub_rec_bankruptcies      0.00      0.00        8.00

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 396030 entries, 0 to 396029
# Data columns (total 27 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   loan_amnt             396030 non-null  float64
#  1   term                  396030 non-null  object
#  2   int_rate              396030 non-null  float64
#  3   installment           396030 non-null  float64
#  4   grade                 396030 non-null  object
#  5   sub_grade             396030 non-null  object
#  6   emp_title             373103 non-null  object
#  7   emp_length            377729 non-null  object
#  8   home_ownership        396030 non-null  object
#  9   annual_inc            396030 non-null  float64
#  10  verification_status   396030 non-null  object
#  11  issue_d               396030 non-null  object
#  12  loan_status           396030 non-null  object
#  13  purpose               396030 non-null  object
#  14  title                 394275 non-null  object
#  15  dti                   396030 non-null  float64
#  16  earliest_cr_line      396030 non-null  object
#  17  open_acc              396030 non-null  float64
#  18  pub_rec               396030 non-null  float64
#  19  revol_bal             396030 non-null  float64
#  20  revol_util            395754 non-null  float64
#  21  total_acc             396030 non-null  float64
#  22  initial_list_status   396030 non-null  object
#  23  application_type      396030 non-null  object
#  24  mort_acc              358235 non-null  float64
#  25  pub_rec_bankruptcies  395495 non-null  float64
#  26  address               396030 non-null  object
# dtypes: float64(12), object(15)
# memory usage: 81.6+ MB

# %%
df.head()
# Out:
#    loan_amnt        term  int_rate  installment grade sub_grade  \
# 0    10000.0   36 months     11.44       329.48     B        B4
# 1     8000.0   36 months     11.99       265.68     B        B5
# 2    15600.0   36 months     10.49       506.97     B        B3
# 3     7200.0   36 months      6.49       220.65     A        A2
# 4    24375.0   60 months     17.27       609.33     C        C5
#
#                  emp_title emp_length home_ownership  annual_inc  ...  \
# 0                Marketing  10+ years           RENT    117000.0  ...
# 1          Credit analyst     4 years       MORTGAGE     65000.0  ...
# 2             Statistician   < 1 year           RENT     43057.0  ...
# 3          Client Advocate    6 years           RENT     54000.0  ...
# 4  Destiny Management Inc.    9 years       MORTGAGE     55000.0  ...
#
#   open_acc pub_rec revol_bal revol_util total_acc  initial_list_status  \
# 0     16.0     0.0   36369.0       41.8      25.0                    w
# 1     17.0     0.0   20131.0       53.3      27.0                    f
# 2     13.0     0.0   11987.0       92.2      26.0                    f
# 3      6.0     0.0    5472.0       21.5      13.0                    f
# 4     13.0     0.0   24584.0       69.8      43.0                    f
#
#   application_type  mort_acc  pub_rec_bankruptcies  \
# 0       INDIVIDUAL       0.0                   0.0
# 1       INDIVIDUAL       3.0                   0.0
# 2       INDIVIDUAL       0.0                   0.0
# 3       INDIVIDUAL       0.0                   0.0
# 4       INDIVIDUAL       1.0                   0.0
#
#                                              address
# 0     0174 Michelle Gateway\r\nMendozaberg, OK 22690
# 1  1076 Carney Fort Apt. 347\r\nLoganmouth, SD 05113
# 2  87025 Mark Dale Apt. 269\r\nNew Sabrina, WV 05113
# 3            823 Reid Ford\r\nDelacruzside, MA 00813
# 4             679 Luna Roads\r\nGreggshire, VA 11650
#
# [5 rows x 27 columns]

# %%
df.isnull().sum()
# Out:
# loan_amnt                   0
# term                        0
# int_rate                    0
# installment                 0
# grade                       0
# sub_grade                   0
# emp_title               22927
# emp_length              18301
# home_ownership              0
# annual_inc                  0
# verification_status         0
# issue_d                     0
# loan_status                 0
# purpose                     0
# title                    1755
# dti                         0
# earliest_cr_line            0
# open_acc                    0
# pub_rec                     0
# revol_bal                   0
# revol_util                276
# total_acc                   0
# initial_list_status         0
# application_type            0
# mort_acc                37795
# pub_rec_bankruptcies      535
# address                     0
# dtype: int64

# %%
100 * df.isnull().sum() / len(df)
# Out:
# loan_amnt               0.000000
# term                    0.000000
# int_rate                0.000000
# installment             0.000000
# grade                   0.000000
# sub_grade               0.000000
# emp_title               5.789208
# emp_length              4.621115
# home_ownership          0.000000
# annual_inc              0.000000
# verification_status     0.000000
# issue_d                 0.000000
# loan_status             0.000000
# purpose                 0.000000
# title                   0.443148
# dti                     0.000000
# earliest_cr_line        0.000000
# open_acc                0.000000
# pub_rec                 0.000000
# revol_bal               0.000000
# revol_util              0.069692
# total_acc               0.000000
# initial_list_status     0.000000
# application_type        0.000000
# mort_acc                9.543469
# pub_rec_bankruptcies    0.135091
# address                 0.000000
# dtype: float64

# %%
#columns having NULL values
columns_having_null = columnNamessHavingNull(df)
pd.DataFrame(columns_having_null)
# Out:
#                       0
# 0             emp_title
# 1            emp_length
# 2                 title
# 3            revol_util
# 4              mort_acc
# 5  pub_rec_bankruptcies

# %%
details_nullcolumns = columnDetailsHaivngNull(columns_having_null)
pd.DataFrame.from_dict([details_nullcolumns])
# Out:
#    emp_title  emp_length  title  revol_util  mort_acc  pub_rec_bankruptcies  \
# 0      22927       18301   1755         276     37795                   535
#
#    Total
# 0  81589

# %%
#Drop Emp_Title as it is not required
df = df.drop(["emp_title"], axis=1)

# %%
columns_having_null = columnNamessHavingNull(df)
pd.DataFrame(columns_having_null)
# Out:
#                       0
# 0            emp_length
# 1                 title
# 2            revol_util
# 3              mort_acc
# 4  pub_rec_bankruptcies

# %%
details_nullcolumns = columnDetailsHaivngNull(columns_having_null)
pd.DataFrame.from_dict([details_nullcolumns])
# Out:
#    emp_length  title  revol_util  mort_acc  pub_rec_bankruptcies  Total
# 0       18301   1755         276     37795                   535  58662

# %%
#Convert 36 months / 60 months to numeric value
df["term"] = df["term"].str.strip()
df["term"] = df["term"].str.split(" ", n = 2, expand = True)

# %%
# Loan Amount vs Loan Status
plt.figure(figsize=(10,6), facecolor="#E0E0E0")
sns.countplot(x='grade', data=df, hue="loan_status", order=sorted(df["grade"].unique()), palette="coolwarm")
plt.show()

# %%
# Loan Amount vs Loan Status
plt.figure(figsize=(10,6), facecolor="#E0E0E0")
sns.countplot(x='sub_grade', data=df, hue="loan_status", order=sorted(df["sub_grade"].unique()), palette="coolwarm")
plt.show()

# %%
plt.figure(figsize=(12,4), facecolor="#E0E0E0")
sns.histplot(df, x='loan_amnt', kde=False, bins=40, hue='loan_status', element='step')
plt.xlim((0, np.max(df['loan_amnt']) + 5000))
plt.show()

# %%
# Loan Amount vs Loan Status
plt.figure(figsize=(10,6), facecolor="#E0E0E0")
sns.kdeplot(data=df, x="loan_amnt", hue="loan_status", shade="1")
plt.show()

# %%
fig, axs = plt.subplots(4, 2, figsize=(25, 15))

sns.countplot(x='home_ownership', data=df, ax=axs[0,0])
l = len(df["home_ownership"].unique())
temp = f"Unique values: {l}"
axs[0,0].legend([temp])

sns.countplot(x='grade', order=sorted(df["grade"].unique()), data=df, ax=axs[0,1])
l = len(df["grade"].unique())
temp = f"Unique values: {l}"
axs[0,1].legend([temp])

sns.countplot(x='sub_grade', order=sorted(df["sub_grade"].unique()), data=df, ax=axs[1,0])
l = len(df["sub_grade"].unique())
temp = f"Unique values: {l}"
axs[1,0].legend([temp])

sns.countplot(x='home_ownership', data=df, ax=axs[1,1])
l = len(df["home_ownership"].unique())
temp = f"Unique values: {l}"
axs[1,1].legend([temp])

sns.countplot(x='loan_status', data=df, ax=axs[2,0])
l = len(df["loan_status"].unique())
temp = f"Unique values: {l}"
axs[2,0].legend([temp])

sns.countplot(x='emp_length', data=df, ax=axs[2,1])
l = len(df["emp_length"].unique())
temp = f"Unique values: {l}"
axs[2,1].legend([temp])

sns.countplot(x='verification_status', data=df, ax=axs[3,0])
l = len(df["verification_status"].unique())
temp = f"Unique values: {l}"
axs[3,0].legend([temp])

plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 396030 entries, 0 to 396029
# Data columns (total 26 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   loan_amnt             396030 non-null  float64
#  1   term                  396030 non-null  object
#  2   int_rate              396030 non-null  float64
#  3   installment           396030 non-null  float64
#  4   grade                 396030 non-null  object
#  5   sub_grade             396030 non-null  object
#  6   emp_length            377729 non-null  object
#  7   home_ownership        396030 non-null  object
#  8   annual_inc            396030 non-null  float64
#  9   verification_status   396030 non-null  object
#  10  issue_d               396030 non-null  object
#  11  loan_status           396030 non-null  object
#  12  purpose               396030 non-null  object
#  13  title                 394275 non-null  object
#  14  dti                   396030 non-null  float64
#  15  earliest_cr_line      396030 non-null  object
#  16  open_acc              396030 non-null  float64
#  17  pub_rec               396030 non-null  float64
#  18  revol_bal             396030 non-null  float64
#  19  revol_util            395754 non-null  float64
#  20  total_acc             396030 non-null  float64
#  21  initial_list_status   396030 non-null  object
#  22  application_type      396030 non-null  object
#  23  mort_acc              358235 non-null  float64
#  24  pub_rec_bankruptcies  395495 non-null  float64
#  25  address               396030 non-null  object
# dtypes: float64(12), object(14)
# memory usage: 78.6+ MB

# %%
createHistUsingPlt(df["loan_amnt"], 30, "Amount of Loan", "Number of People", "Loan Club", ["Amount of loan"], "RishabArora.com")

# %%
label_encoder = preprocessing.LabelEncoder()

# %%
df.head(5)
# Out:
#    loan_amnt term  int_rate  installment grade sub_grade emp_length  \
# 0    10000.0   36     11.44       329.48     B        B4  10+ years
# 1     8000.0   36     11.99       265.68     B        B5    4 years
# 2    15600.0   36     10.49       506.97     B        B3   < 1 year
# 3     7200.0   36      6.49       220.65     A        A2    6 years
# 4    24375.0   60     17.27       609.33     C        C5    9 years
#
#   home_ownership  annual_inc verification_status  ... open_acc pub_rec  \
# 0           RENT    117000.0        Not Verified  ...     16.0     0.0
# 1       MORTGAGE     65000.0        Not Verified  ...     17.0     0.0
# 2           RENT     43057.0     Source Verified  ...     13.0     0.0
# 3           RENT     54000.0        Not Verified  ...      6.0     0.0
# 4       MORTGAGE     55000.0            Verified  ...     13.0     0.0
#
#   revol_bal revol_util  total_acc initial_list_status  application_type  \
# 0   36369.0       41.8       25.0                   w        INDIVIDUAL
# 1   20131.0       53.3       27.0                   f        INDIVIDUAL
# 2   11987.0       92.2       26.0                   f        INDIVIDUAL
# 3    5472.0       21.5       13.0                   f        INDIVIDUAL
# 4   24584.0       69.8       43.0                   f        INDIVIDUAL
#
#    mort_acc  pub_rec_bankruptcies  \
# 0       0.0                   0.0
# 1       3.0                   0.0
# 2       0.0                   0.0
# 3       0.0                   0.0
# 4       1.0                   0.0
#
#                                              address
# 0     0174 Michelle Gateway\r\nMendozaberg, OK 22690
# 1  1076 Carney Fort Apt. 347\r\nLoganmouth, SD 05113
# 2  87025 Mark Dale Apt. 269\r\nNew Sabrina, WV 05113
# 3            823 Reid Ford\r\nDelacruzside, MA 00813
# 4             679 Luna Roads\r\nGreggshire, VA 11650
#
# [5 rows x 26 columns]

# %%
#Change column grade to numeric.
df["grade"]= label_encoder.fit_transform(df["grade"])

# %%
#Drop sub grade. Grade and subgrade are forming the similar chart. sub grade has 37 categories. So dropping it
df = df.drop("sub_grade", axis=1)

# %%
emp_length_unique = df['emp_length'].unique().tolist()
# emp_length_unique = ['10+ years',
#  '4 years',
#  '< 1 year',
#  '6 years',
#  '9 years',
#  '2 years',
#  '3 years',
#  '8 years',
#  '7 years',
#  '5 years',
#  '1 year',
#  nan]

emp_length = df['emp_length'].tolist()
new_emp_length = []

for x in emp_length:
    if x == emp_length_unique[0]:
        new_emp_length.append(10)
    elif x == emp_length_unique[1]:
        new_emp_length.append(4)
    elif x == emp_length_unique[2]:
        new_emp_length.append(0)
    elif x == emp_length_unique[3]:
        new_emp_length.append(6)
    elif x == emp_length_unique[4]:
        new_emp_length.append(9)
    elif x == emp_length_unique[5]:
        new_emp_length.append(2)
    elif x == emp_length_unique[6]:
        new_emp_length.append(3)
    elif x == emp_length_unique[7]:
        new_emp_length.append(8)
    elif x == emp_length_unique[8]:
        new_emp_length.append(7)
    elif x == emp_length_unique[9]:
        new_emp_length.append(5)
    elif x == emp_length_unique[10]:
        new_emp_length.append(1)
    else:
        new_emp_length.append(-1)
        
df['emp_length'] = pd.Series(new_emp_length)

# %%
#Change home ownership to numeric values
#Change column grade to numeric.
df["home_ownership"]= label_encoder.fit_transform(df["home_ownership"])

# %%
df["loan_status"]= label_encoder.fit_transform(df["loan_status"])

# %%
df["verification_status"]= label_encoder.fit_transform(df["verification_status"])

# %%
df.corr()["verification_status"]
# Out:
# loan_amnt               0.310671
# int_rate                0.236406
# installment             0.296788
# grade                   0.219524
# emp_length             -0.000552
# home_ownership         -0.058982
# annual_inc              0.081114
# verification_status     1.000000
# loan_status            -0.077909
# dti                     0.050504
# open_acc                0.065512
# pub_rec                 0.043091
# revol_bal               0.109085
# revol_util              0.073818
# total_acc               0.089730
# mort_acc                0.087324
# pub_rec_bankruptcies    0.029834
# Name: verification_status, dtype: float64

# %%
df.corr()["emp_length"].sort_values(ascending=False)
# Out:
# emp_length              1.000000
# mort_acc                0.171096
# loan_amnt               0.119899
# total_acc               0.114582
# installment             0.106264
# annual_inc              0.095140
# revol_bal               0.090352
# open_acc                0.058110
# revol_util              0.045203
# loan_status             0.028938
# pub_rec                 0.014456
# pub_rec_bankruptcies    0.012575
# int_rate                0.009498
# dti                     0.007969
# grade                   0.003982
# verification_status    -0.000552
# home_ownership         -0.185400
# Name: emp_length, dtype: float64

# %%
df = df.drop("emp_length", axis=1)

# %%
df = df.drop("title", axis=1)

# %%
df.corr()["revol_util"].sort_values(ascending=False)
# Out:
# revol_util              1.000000
# int_rate                0.293659
# grade                   0.258950
# revol_bal               0.226346
# installment             0.123915
# loan_amnt               0.099911
# dti                     0.088375
# verification_status     0.073818
# annual_inc              0.027871
# mort_acc                0.007514
# home_ownership         -0.009240
# pub_rec                -0.075910
# loan_status            -0.082373
# pub_rec_bankruptcies   -0.086751
# total_acc              -0.104273
# open_acc               -0.131420
# Name: revol_util, dtype: float64

# %%
df["revol_util"].describe()
# Out:
# count    395754.000000
# mean         53.791749
# std          24.452193
# min           0.000000
# 25%          35.800000
# 50%          54.800000
# 75%          72.900000
# max         892.300000
# Name: revol_util, dtype: float64

# %%
#Fill "revol_util" with mean values where blank or NAN
df["revol_util"].fillna((df["revol_util"].mean()), inplace=True)

# %%
df.corr()["mort_acc"].sort_values(ascending=False)
# Out:
# mort_acc                1.000000
# total_acc               0.381072
# annual_inc              0.236320
# loan_amnt               0.222315
# revol_bal               0.194925
# installment             0.193694
# open_acc                0.109205
# verification_status     0.087324
# loan_status             0.073111
# pub_rec_bankruptcies    0.027239
# pub_rec                 0.011552
# revol_util              0.007510
# dti                    -0.025439
# grade                  -0.075255
# int_rate               -0.082583
# home_ownership         -0.486116
# Name: mort_acc, dtype: float64

# %%
df["mort_acc"].describe()
# Out:
# count    358235.000000
# mean          1.813991
# std           2.147930
# min           0.000000
# 25%           0.000000
# 50%           1.000000
# 75%           3.000000
# max          34.000000
# Name: mort_acc, dtype: float64

# %%
df["mort_acc"].median()
# Out:
# 1.0

# %%
# Loan Amount vs Loan Status
plt.figure(figsize=(10,6), facecolor="#E0E0E0")
sns.countplot(x='mort_acc', data=df, palette="coolwarm")
plt.show()

# %%
df["mort_acc"].fillna((df["mort_acc"].median()), inplace=True)

# %%
df["mort_acc"].describe()
# Out:
# count    396030.000000
# mean          1.736308
# std           2.056819
# min           0.000000
# 25%           0.000000
# 50%           1.000000
# 75%           3.000000
# max          34.000000
# Name: mort_acc, dtype: float64

# %%
df["total_acc"].describe()
# Out:
# count    396030.000000
# mean         25.414744
# std          11.886991
# min           2.000000
# 25%          17.000000
# 50%          24.000000
# 75%          32.000000
# max         151.000000
# Name: total_acc, dtype: float64

# %%
df["pub_rec_bankruptcies"].describe()
# Out:
# count    395495.000000
# mean          0.121648
# std           0.356174
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max           8.000000
# Name: pub_rec_bankruptcies, dtype: float64

# %%
# Loan Amount vs Loan Status
plt.figure(figsize=(10,6), facecolor="#E0E0E0")
sns.countplot(x='pub_rec_bankruptcies', data=df, palette="coolwarm")
plt.show()

# %%
m = df["pub_rec_bankruptcies"].mode()
df["pub_rec_bankruptcies"].fillna((m.iloc[0]), inplace=True)

# %%
df.corr()["pub_rec_bankruptcies"]
# Out:
# loan_amnt              -0.106227
# int_rate                0.057734
# installment            -0.098344
# grade                   0.061611
# home_ownership          0.008684
# annual_inc             -0.050043
# verification_status     0.030383
# loan_status            -0.009416
# dti                    -0.014384
# open_acc               -0.027534
# pub_rec                 0.699380
# revol_bal              -0.124405
# revol_util             -0.086399
# total_acc               0.042229
# mort_acc                0.035249
# pub_rec_bankruptcies    1.000000
# Name: pub_rec_bankruptcies, dtype: float64

# %%
df.isnull().sum()
# Out:
# loan_amnt               0
# term                    0
# int_rate                0
# installment             0
# grade                   0
# home_ownership          0
# annual_inc              0
# verification_status     0
# issue_d                 0
# loan_status             0
# purpose                 0
# dti                     0
# earliest_cr_line        0
# open_acc                0
# pub_rec                 0
# revol_bal               0
# revol_util              0
# total_acc               0
# initial_list_status     0
# application_type        0
# mort_acc                0
# pub_rec_bankruptcies    0
# address                 0
# dtype: int64

# %%
df["application_type"]= label_encoder.fit_transform(df["application_type"])

# %%
pincode = df["address"].str[-5:]

# %%
df['address'] = pd.Series(pincode)

# %%
df["initial_list_status"]= label_encoder.fit_transform(df["initial_list_status"])

# %%
month_number = df['issue_d'].str[:3]
d = {'Jan':1, 'Feb':2, 'Mar':3, 'Apr':4,'May':5, 'Jun':6, 'Jul':7, 'Aug':8,'Sep':9, 'Oct':10, 'Nov':11, 'Dec':12}
df['month_number'] = pd.Series(month_number)
df['month_number'] = df['month_number'].map(d)

year_number = df['issue_d'].str[-4:]
df['year_number'] = pd.Series(year_number)
df["year_number"]= label_encoder.fit_transform(df["year_number"])
# df["issue_d"] =  pd.to_datetime(df["issue_d"], format='%b-%Y')
# df['issue_d'].apply(lambda x: x.toordinal())

# %%
df = df.drop(["issue_d"], axis=1)

# %%
df = df.drop(["purpose"], axis=1)

# %%
df["term"]= label_encoder.fit_transform(df["term"])

# %%
df["address"] = pd.to_numeric(df["address"])

# %%
month_number = df['earliest_cr_line'].str[:3]
d = {'Jan':1, 'Feb':2, 'Mar':3, 'Apr':4,'May':5, 'Jun':6, 'Jul':7, 'Aug':8,'Sep':9, 'Oct':10, 'Nov':11, 'Dec':12}
df['earliest_cr_line_mon'] = pd.Series(month_number)
df['earliest_cr_line_mon'] = df['earliest_cr_line_mon'].map(d)

year_number = df['earliest_cr_line'].str[-4:]
df['earliest_cr_line_year'] = pd.Series(year_number)
df["earliest_cr_line_year"]= label_encoder.fit_transform(df["earliest_cr_line_year"])

# %%
df = df.drop(["earliest_cr_line"], axis=1)

# %%
df.head(5)
# Out:
#    loan_amnt  term  int_rate  installment  grade  home_ownership  annual_inc  \
# 0    10000.0     0     11.44       329.48      1               5    117000.0
# 1     8000.0     0     11.99       265.68      1               1     65000.0
# 2    15600.0     0     10.49       506.97      1               5     43057.0
# 3     7200.0     0      6.49       220.65      0               5     54000.0
# 4    24375.0     1     17.27       609.33      2               1     55000.0
#
#    verification_status  loan_status    dti  ...  total_acc  \
# 0                    0            1  26.24  ...       25.0
# 1                    0            1  22.05  ...       27.0
# 2                    1            1  12.79  ...       26.0
# 3                    0            1   2.60  ...       13.0
# 4                    2            0  33.95  ...       43.0
#
#    initial_list_status  application_type  mort_acc  pub_rec_bankruptcies  \
# 0                    1                 1       0.0                   0.0
# 1                    0                 1       3.0                   0.0
# 2                    0                 1       0.0                   0.0
# 3                    0                 1       0.0                   0.0
# 4                    0                 1       1.0                   0.0
#
#    address  month_number  year_number  earliest_cr_line_mon  \
# 0    22690             1            8                     6
# 1     5113             1            8                     7
# 2     5113             1            8                     8
# 3      813            11            7                     9
# 4    11650             4            6                     3
#
#    earliest_cr_line_year
# 0                     41
# 1                     55
# 2                     58
# 3                     57
# 4                     50
#
# [5 rows x 24 columns]

# %%
# correlation heat map
plt.figure(figsize=(12, 6))
df_corr = df.corr()

# min -1 and max +1 as we are plotting correlation
sns.heatmap(df.corr(), cmap="Blues", annot=True, fmt=".2f", vmin= -1.0, vmax=1.0,
           linewidth=0.3, cbar_kws={"shrink": .8})
# yticks
plt.yticks(rotation=0)
plt.show()

# %%
df.corr()["loan_status"].sort_values(ascending=False)
# Out:
# loan_status              1.000000
# mort_acc                 0.065059
# annual_inc               0.053432
# total_acc                0.017893
# month_number             0.016368
# application_type         0.011296
# revol_bal                0.010892
# earliest_cr_line_mon     0.003861
# pub_rec_bankruptcies    -0.009416
# initial_list_status     -0.009489
# pub_rec                 -0.019933
# open_acc                -0.028012
# earliest_cr_line_year   -0.038932
# installment             -0.041082
# loan_amnt               -0.059836
# year_number             -0.060502
# dti                     -0.062413
# home_ownership          -0.068370
# verification_status     -0.077909
# revol_util              -0.082341
# term                    -0.173246
# int_rate                -0.247758
# grade                   -0.257286
# address                 -0.346862
# Name: loan_status, dtype: float64

# %%
df = df.drop("earliest_cr_line_mon", axis=1)

# %%
df = df.drop("month_number", axis=1)

# %%
df = df.drop("pub_rec_bankruptcies", axis=1)

# %%
df = df.drop("initial_list_status", axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 396030 entries, 0 to 396029
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   loan_amnt              396030 non-null  float64
#  1   term                   396030 non-null  int64
#  2   int_rate               396030 non-null  float64
#  3   installment            396030 non-null  float64
#  4   grade                  396030 non-null  int64
#  5   home_ownership         396030 non-null  int64
#  6   annual_inc             396030 non-null  float64
#  7   verification_status    396030 non-null  int64
#  8   loan_status            396030 non-null  int64
#  9   dti                    396030 non-null  float64
#  10  open_acc               396030 non-null  float64
#  11  pub_rec                396030 non-null  float64
#  12  revol_bal              396030 non-null  float64
#  13  revol_util             396030 non-null  float64
#  14  total_acc              396030 non-null  float64
#  15  application_type       396030 non-null  int64
#  16  mort_acc               396030 non-null  float64
#  17  address                396030 non-null  int64
#  18  year_number            396030 non-null  int64
#  19  earliest_cr_line_year  396030 non-null  int64
# dtypes: float64(11), int64(9)
# memory usage: 60.4 MB

# %%
X = df.drop('loan_status', axis=1).values
y = df['loan_status'].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
X_train.shape
# Out:
# (277221, 19)

# %%
early_stop = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=7)

# %%
model = Sequential()

model.add(Dense(23, activation='relu'))
model.add(Dropout(0.15))

model.add(Dense(32, activation='relu'))
model.add(Dropout(0.15))

model.add(Dense(32, activation='relu'))
model.add(Dropout(0.15))

# model.add(Dense(64, activation='relu'))
# model.add(Dropout(0.1))

# Binary classification problem
model.add(Dense(1, activation='sigmoid'))

model.compile(loss='binary_crossentropy', optimizer='adam')

# %%
model.fit(x=X_train, y=y_train, epochs=40, validation_split=0.3,batch_size=200, callbacks=[early_stop])
# Out:
# Epoch 1/40
# 777/777 [==============================] - 2s 2ms/step - loss: 0.4296 - val_loss: 0.3775
# Epoch 2/40
# 777/777 [==============================] - 2s 2ms/step - loss: 0.3816 - val_loss: 0.3592
# Epoch 3/40
# 777/777 [==============================] - 2s 2ms/step - loss: 0.3708 - val_loss: 0.3571
# Epoch 4/40
# 777/777 [==============================] - 2s 2ms/step - loss: 0.3660 - val_loss: 0.3531
# Epoch 5/40
# 777/777 [==============================] - 2s 2ms/step - loss: 0.3532 - val_loss: 0.3243
# Epoch 6/40
# 777/777 [==============================] - 2s 2ms/step - loss: 0.3238 - val_loss: 0.2930
# Epoch 7/40
# 777/777 [==============================] - 2s 2ms/step - loss: 0.3008 - val_loss: 0.2817
# Epoch 8/40
# 777/777 [==============================] - 2s 2ms/step - loss: 0.2924 - val_loss: 0.2791
# Epoch 9/40
# 777/777 [==============================] - 2s 2ms/step - loss: 0.2888 - val_loss: 0.2788
# Epoch 10/40
# 777/777 [==============================] - 2s 2ms/step - loss: 0.2864 - val_loss: 0.2783
# Epoch 11/40
# 777/777 [==============================] - 2s 2ms/step - loss: 0.2851 - val_loss: 0.2772
# Epoch 12/40
# 777/777 [==============================] - 2s 2ms/step - loss: 0.2839 - val_loss: 0.2767
# Epoch 13/40
# 777/777 [==============================] - 2s 2ms/step - loss: 0.2833 - val_loss: 0.2772
# Epoch 14/40
# 777/777 [==============================] - 2s 2ms/step - loss: 0.2826 - val_loss: 0.2760
# Epoch 15/40
# 777/777 [==============================] - 2s 2ms/step - loss: 0.2819 - val_loss: 0.2764
# Epoch 16/40
# 777/777 [==============================] - 2s 2ms/step - loss: 0.2813 - val_loss: 0.2747
# Epoch 17/40
# 777/777 [==============================] - 2s 2ms/step - loss: 0.2816 - val_loss: 0.2752
# Epoch 18/40
# 777/777 [==============================] - 2s 2ms/step - loss: 0.2807 - val_loss: 0.2753
# Epoch 19/40
# 777/777 [==============================] - 2s 2ms/step - loss: 0.2806 - val_loss: 0.2755
# Epoch 20/40
# 777/777 [==============================] - 2s 2ms/step - loss: 0.2799 - val_loss: 0.2748
# Epoch 21/40
# 777/777 [==============================] - 2s 2ms/step - loss: 0.2798 - val_loss: 0.2741
# Epoch 22/40
# 777/777 [==============================] - 2s 2ms/step - loss: 0.2793 - val_loss: 0.2741
# Epoch 23/40
# 777/777 [==============================] - 2s 2ms/step - loss: 0.2795 - val_loss: 0.2741
# Epoch 24/40
# 777/777 [==============================] - 2s 2ms/step - loss: 0.2790 - val_loss: 0.2735
# Epoch 25/40
# 777/777 [==============================] - 2s 2ms/step - loss: 0.2790 - val_loss: 0.2745
# Epoch 26/40
# 777/777 [==============================] - 2s 2ms/step - loss: 0.2790 - val_loss: 0.2735
# Epoch 27/40
# 777/777 [==============================] - 2s 2ms/step - loss: 0.2784 - val_loss: 0.2739
# Epoch 28/40
# 777/777 [==============================] - 2s 2ms/step - loss: 0.2782 - val_loss: 0.2739
# Epoch 29/40
# 777/777 [==============================] - 2s 2ms/step - loss: 0.2783 - val_loss: 0.2731
# Epoch 30/40
# 777/777 [==============================] - 2s 2ms/step - loss: 0.2783 - val_loss: 0.2733
# Epoch 31/40
# 777/777 [==============================] - 2s 2ms/step - loss: 0.2780 - val_loss: 0.2743
# Epoch 32/40
# 777/777 [==============================] - 2s 2ms/step - loss: 0.2776 - val_loss: 0.2732
# Epoch 33/40
# 777/777 [==============================] - 2s 2ms/step - loss: 0.2776 - val_loss: 0.2738
# Epoch 34/40
# 777/777 [==============================] - 2s 2ms/step - loss: 0.2776 - val_loss: 0.2725
# Epoch 35/40
# 777/777 [==============================] - 2s 2ms/step - loss: 0.2775 - val_loss: 0.2733
# Epoch 36/40
# 777/777 [==============================] - 2s 2ms/step - loss: 0.2769 - val_loss: 0.2744
# Epoch 37/40
# 777/777 [==============================] - 2s 2ms/step - loss: 0.2770 - val_loss: 0.2713
# Epoch 38/40
# 777/777 [==============================] - 2s 2ms/step - loss: 0.2775 - val_loss: 0.2730
# Epoch 39/40
# 777/777 [==============================] - 2s 2ms/step - loss: 0.2766 - val_loss: 0.2718
# Epoch 40/40
# 777/777 [==============================] - 2s 2ms/step - loss: 0.2765 - val_loss: 0.2709

# %%
losses = pd.DataFrame(model.history.history)

# %%
losses.plot()
# Out:
# <AxesSubplot:>

# %%
predictions = model.predict_classes(X_test)
# Out:
# WARNING:tensorflow:From <ipython-input-79-bc83193b8b59>:1: Sequential.predict_classes (from tensorflow.python.keras.engine.sequential) is deprecated and will be removed after 2021-01-01.
# Instructions for updating:
# Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).

# %%
print(classification_report(y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.43      0.61     23260
#            1       0.88      1.00      0.94     95549
#
#     accuracy                           0.89    118809
#    macro avg       0.94      0.72      0.77    118809
# weighted avg       0.90      0.89      0.87    118809

# %%
print(confusion_matrix(y_test, predictions))
# Out:
# [[10112 13148]
#  [   51 95498]]
